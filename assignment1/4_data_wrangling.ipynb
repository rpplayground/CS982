# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
# ms-python.python added
import os
try:
	os.chdir(os.path.join(os.getcwd(), '..'))
	print(os.getcwd())
except:
	pass

# %% [markdown]
# # University of Strathclyde -  MSc Artificial Intelligence and Applications
# # CS982 - Big Data Technologies
# # Assignment 1 - Exploring Data
#  File Created first created 9th October 2019 by Barry Smart.
#
# ## Stage 4 - Data Wrangling
#  The purpose of this notebook is to orchestrate the process of wanrgling the data.
#  This has been tackled by completing each of the backlog items classed as "Data Wrangling" and placing them into a logica sequence in the notebook:
#
#  1. Ingestion
#  2. Trimming
#  3. Filtering
#  4. Process Blank Cells
#  5. Unpivoting
#  6. Add Country Netadata
#  7. Add Decade Label
#  8. Pivoting
#  9. Write To File
#
# ### Design Decisions
#  - The notebook is structured such that it can be run end to end any time a new data cut becomes available to transform the raw data into a consistent format for downstream analysis.
#  - Any heavy blocks of code have been written as functions in a seperate "data_wrangling_functions.py" Python file and imported into this notebook.
#  - The introduction of multi-indexing is extremely useful for downstream processing.
#  - Other fundamental processing of data to support downstream analysis has been "retrofitted" to this stage of the process, so we do not need to keep repeating elsewhere and can do it once and re-use it accordingly - eg setting up a "Decade" column.
#
# ### Stage 4.1 - Ingest Data
#  First stage is to load the raw data from CSV files as generated from the World Bank's [open data portal](https://databank.worldbank.org/).
#  Two files are of interest:
#  - The larger file containing "world development indicators" organised by country and year.
#  - A smaller "coutry metadata" file containing classifications for each coutry such as region and income group.

# %%
import numpy as np
import pandas as pd
import os
import assignment1.helper_functions as hf

# %%
# Read the raw World Bank data from the CSV file
data_path = str(os.getcwd()) + "\\assignment1\\"
raw_worldbank_data = pd.read_csv(data_path + "world_bank_data.csv")

# %%
raw_worldbank_country_metadata = pd.read_csv(data_path + "world_bank_country_metadata.csv")

# %%
raw_worldbank_country_metadata.loc[raw_worldbank_country_metadata["Code"] == "PRK"]
# Out:
#     Code                              Long Name Income Group  \
# 103  PRK  Democratic People's Republic of Korea   Low income
#
#                   Region Lending category Other groups  \
# 103  East Asia & Pacific              NaN          NaN
#
#                                   Currency Unit Latest population census  \
# 103  Democratic People's Republic of Korean won                     2008
#
#                      Latest household survey Special Notes  ...  \
# 103  Multiple Indicator Cluster Survey, 2017           NaN  ...
#
#     IMF data dissemination standard  \
# 103                             NaN
#
#     Source of most recent Income and expenditure data  \
# 103                                               NaN
#
#     Vital registration complete Latest agricultural census  \
# 103                         NaN                        NaN
#
#     Latest industrial data Latest trade data 2-alpha code WB-2 code  \
# 103                    NaN            2016.0           KP        KP
#
#                     Table Name                Short Name
# 103  Korea, Dem. People's Rep.  Dem. People's Rep. Korea
#
# [1 rows x 30 columns]

# %%
raw_worldbank_data.head(10)
# Out:
#   Country Name Country Code                                 Series Name  \
# 0  Afghanistan          AFG                           GDP (current US$)
# 1  Afghanistan          AFG                       GDP growth (annual %)
# 2  Afghanistan          AFG                           Population, total
# 3  Afghanistan          AFG    Population, male (% of total population)
# 4  Afghanistan          AFG  Population, female (% of total population)
# 5  Afghanistan          AFG    Life expectancy at birth, female (years)
# 6  Afghanistan          AFG      Life expectancy at birth, male (years)
# 7  Afghanistan          AFG     Life expectancy at birth, total (years)
# 8  Afghanistan          AFG                GDP per capita (current US$)
# 9  Afghanistan          AFG            GDP per capita growth (annual %)
#
#          Series Code     1960 [YR1960]     1961 [YR1961]     1962 [YR1962]  \
# 0     NY.GDP.MKTP.CD  537777811.111111  548888895.555556  546666677.777778
# 1  NY.GDP.MKTP.KD.ZG                ..                ..                ..
# 2        SP.POP.TOTL           8996973           9169410           9351441
# 3  SP.POP.TOTL.MA.ZS  51.6793381591819  51.5873111082659  51.5006134882727
# 4  SP.POP.TOTL.FE.ZS  48.3206618408181  48.4126888917341  48.4993865117273
# 5  SP.DYN.LE00.FE.IN            33.314             33.84            34.359
# 6  SP.DYN.LE00.MA.IN            31.718            32.224            32.724
# 7     SP.DYN.LE00.IN            32.446            32.962            33.471
# 8     NY.GDP.PCAP.CD  59.7731938409853  59.8608738790779  58.4580149495439
# 9  NY.GDP.PCAP.KD.ZG                ..                ..                ..
#
#       1963 [YR1963]     1964 [YR1964]     1965 [YR1965]  ...  \
# 0  751111191.111111  800000044.444444  1006666637.77778  ...
# 1                ..                ..                ..  ...
# 2           9543205           9744781           9956320  ...
# 3  51.4191256601559  51.3428636401139  51.2716146671892  ...
# 4  48.5808743398441  48.6571363598861  48.7283853328108  ...
# 5            34.866            35.364            35.853  ...
# 6            33.216              33.7             34.18  ...
# 7            33.971            34.463            34.948  ...
# 8  78.7063875407802  82.0952307131832  101.108304853377  ...
# 9                ..                ..                ..  ...
#
#       2009 [YR2009]     2010 [YR2010]      2011 [YR2011]     2012 [YR2012]  \
# 0  12439087076.7667  15856574731.4411   17804280538.1102  20001615788.6719
# 1   21.390528405312  14.3624414596815  0.426354792856571  12.7522870825788
# 2          28394813          29185507           30117413          31161376
# 3  51.2208289079348  51.1752424002444    51.184216996607  51.2328883530119
# 4  48.7791710920652  48.8247575997556    48.815783003393  48.7671116469881
# 5            61.898            62.459                 63            63.514
# 6            59.159            59.683              60.19            60.675
# 7            60.484            61.028             61.553            62.054
# 8  438.076034406941  543.303041863931    591.16234645088  641.872033785411
# 9  18.5153687132188   11.264133238155   -2.6810808487635  8.97487956759649
#
#       2013 [YR2013]       2014 [YR2014]     2015 [YR2015]       2016 [YR2016]  \
# 0  20561054090.3995    20484873230.2111  19907111418.9938    19362642266.6484
# 1  5.60074466131904    2.72454336495028  1.45131465458005     2.2603142045464
# 2          32269589            33370794          34413603            35383128
# 3  51.2999296675334    51.3586756854884   51.392950630598    51.4003323853459
# 4  48.7000703324666    48.6413243145116   48.607049369402    48.5996676146541
# 5            63.999              64.453            64.877              65.275
# 6            61.133              61.563            61.965              62.343
# 7            62.525              62.966            63.377              63.763
# 8   637.16504385598    613.856332882312  578.466352941708    547.228110150363
# 9  1.97416862890181  -0.665270517698119  -1.6228866716696  -0.541697283221509
#
#       2017 [YR2017]      2018 [YR2018]
# 0  20191764940.1602   19362969582.3643
# 1  2.66529204636834   1.03066005804328
# 2          36296400           37172386
# 3   51.388384281721   51.3641532982879
# 4   48.611615718279   48.6358467017121
# 5            65.656                 ..
# 6            62.701                 ..
# 7             64.13                 ..
# 8  556.302138508508   520.896602719135
# 9  0.08207892887539  -1.35017833585495
#
# [10 rows x 63 columns]

# %% [markdown]
# ### Stage 4.2 - Trimming
#  This part of the process will:
#  - Trim the last 5 rows from the data set as they do not contain data (could be considered redundant given next step below);

# %%
raw_worldbank_data.tail(10)
# Out:
#                                            Country Name Country Code  \
# 21907                                             World          WLD
# 21908                                             World          WLD
# 21909                                             World          WLD
# 21910                                             World          WLD
# 21911                                             World          WLD
# 21912                                               NaN          NaN
# 21913                                               NaN          NaN
# 21914                                               NaN          NaN
# 21915  Data from database: World Development Indicators          NaN
# 21916                          Last Updated: 10/16/2019          NaN
#
#                                              Series Name     Series Code  \
# 21907  Mortality rate, adult, male (per 1,000 male ad...  SP.DYN.AMRT.MA
# 21908  Mortality rate, adult, female (per 1,000 femal...  SP.DYN.AMRT.FE
# 21909  Mortality rate attributed to unsafe water, uns...  SH.STA.WASH.P5
# 21910  Mortality rate attributed to unintentional poi...  SH.STA.POIS.P5
# 21911       Central government debt, total (current LCU)  GC.DOD.TOTL.CN
# 21912                                                NaN             NaN
# 21913                                                NaN             NaN
# 21914                                                NaN             NaN
# 21915                                                NaN             NaN
# 21916                                                NaN             NaN
#
#           1960 [YR1960]     1961 [YR1961]     1962 [YR1962]     1963 [YR1963]  \
# 21907  371.870167591872  366.620519405922   362.93021625082  351.297410830587
# 21908  297.893994349911  293.223969718727  289.821387467588  281.071338723073
# 21909                ..                ..                ..                ..
# 21910                ..                ..                ..                ..
# 21911                ..                ..                ..                ..
# 21912               NaN               NaN               NaN               NaN
# 21913               NaN               NaN               NaN               NaN
# 21914               NaN               NaN               NaN               NaN
# 21915               NaN               NaN               NaN               NaN
# 21916               NaN               NaN               NaN               NaN
#
#           1964 [YR1964]     1965 [YR1965]  ...     2009 [YR2009]  \
# 21907  338.708444497898  328.205638930645  ...  190.444190345198
# 21908  271.804581893746  263.635971813592  ...  128.008201054076
# 21909                ..                ..  ...                ..
# 21910                ..                ..  ...                ..
# 21911                ..                ..  ...                ..
# 21912               NaN               NaN  ...               NaN
# 21913               NaN               NaN  ...               NaN
# 21914               NaN               NaN  ...               NaN
# 21915               NaN               NaN  ...               NaN
# 21916               NaN               NaN  ...               NaN
#
#           2010 [YR2010]     2011 [YR2011]     2012 [YR2012]     2013 [YR2013]  \
# 21907  187.635427959727  184.823696637169  182.462455416421  180.099127354713
# 21908  124.993294650045  122.227902527935  119.529053980065  117.871409920965
# 21909                ..                ..                ..                ..
# 21910  1.62406434494835                ..                ..                ..
# 21911                ..                ..                ..                ..
# 21912               NaN               NaN               NaN               NaN
# 21913               NaN               NaN               NaN               NaN
# 21914               NaN               NaN               NaN               NaN
# 21915               NaN               NaN               NaN               NaN
# 21916               NaN               NaN               NaN               NaN
#
#           2014 [YR2014]     2015 [YR2015]     2016 [YR2016]     2017 [YR2017]  \
# 21907  177.298309844609  174.085100929693  173.472867275604  178.318112520384
# 21908  116.391670742655  116.083524344293   115.54781327774  119.911900229058
# 21909                ..                ..  11.7590910002673                ..
# 21910                ..  1.46411063791079  1.45141154191923                ..
# 21911                ..                ..                ..                ..
# 21912               NaN               NaN               NaN               NaN
# 21913               NaN               NaN               NaN               NaN
# 21914               NaN               NaN               NaN               NaN
# 21915               NaN               NaN               NaN               NaN
# 21916               NaN               NaN               NaN               NaN
#
#       2018 [YR2018]
# 21907            ..
# 21908            ..
# 21909            ..
# 21910            ..
# 21911            ..
# 21912           NaN
# 21913           NaN
# 21914           NaN
# 21915           NaN
# 21916           NaN
#
# [10 rows x 63 columns]

# %%
trimmed_worldbank_data = raw_worldbank_data.head(-5)

# %%
trimmed_worldbank_data.tail(10)
# Out:
#       Country Name Country Code  \
# 21902        World          WLD
# 21903        World          WLD
# 21904        World          WLD
# 21905        World          WLD
# 21906        World          WLD
# 21907        World          WLD
# 21908        World          WLD
# 21909        World          WLD
# 21910        World          WLD
# 21911        World          WLD
#
#                                              Series Name        Series Code  \
# 21902  Suicide mortality rate, male (per 100,000 male...  SH.STA.SUIC.MA.P5
# 21903   Mortality rate, neonatal (per 1,000 live births)        SH.DYN.NMRT
# 21904     Mortality rate, infant (per 1,000 live births)     SP.DYN.IMRT.IN
# 21905  Mortality from CVD, cancer, diabetes or CRD be...     SH.DYN.NCOM.ZS
# 21906    Mortality rate, under-5 (per 1,000 live births)        SH.DYN.MORT
# 21907  Mortality rate, adult, male (per 1,000 male ad...     SP.DYN.AMRT.MA
# 21908  Mortality rate, adult, female (per 1,000 femal...     SP.DYN.AMRT.FE
# 21909  Mortality rate attributed to unsafe water, uns...     SH.STA.WASH.P5
# 21910  Mortality rate attributed to unintentional poi...     SH.STA.POIS.P5
# 21911       Central government debt, total (current LCU)     GC.DOD.TOTL.CN
#
#           1960 [YR1960]     1961 [YR1961]     1962 [YR1962]     1963 [YR1963]  \
# 21902                ..                ..                ..                ..
# 21903                ..                ..                ..                ..
# 21904                ..                ..                ..                ..
# 21905                ..                ..                ..                ..
# 21906                ..                ..                ..                ..
# 21907  371.870167591872  366.620519405922   362.93021625082  351.297410830587
# 21908  297.893994349911  293.223969718727  289.821387467588  281.071338723073
# 21909                ..                ..                ..                ..
# 21910                ..                ..                ..                ..
# 21911                ..                ..                ..                ..
#
#           1964 [YR1964]     1965 [YR1965]  ...     2009 [YR2009]  \
# 21902                ..                ..  ...                ..
# 21903                ..                ..  ...              22.8
# 21904                ..                ..  ...              38.4
# 21905                ..                ..  ...                ..
# 21906                ..                ..  ...              53.2
# 21907  338.708444497898  328.205638930645  ...  190.444190345198
# 21908  271.804581893746  263.635971813592  ...  128.008201054076
# 21909                ..                ..  ...                ..
# 21910                ..                ..  ...                ..
# 21911                ..                ..  ...                ..
#
#           2010 [YR2010]     2011 [YR2011]     2012 [YR2012]     2013 [YR2013]  \
# 21902  14.3265740762378                ..                ..                ..
# 21903              22.1              21.4              20.8              20.2
# 21904              37.1              35.7              34.5              33.4
# 21905  19.8042936893589                ..                ..                ..
# 21906              51.3                49              47.1              45.4
# 21907  187.635427959727  184.823696637169  182.462455416421  180.099127354713
# 21908  124.993294650045  122.227902527935  119.529053980065  117.871409920965
# 21909                ..                ..                ..                ..
# 21910  1.62406434494835                ..                ..                ..
# 21911                ..                ..                ..                ..
#
#           2014 [YR2014]     2015 [YR2015]     2016 [YR2016]     2017 [YR2017]  \
# 21902                ..  13.6224442620525  13.5057595189264                ..
# 21903              19.6              19.1              18.6              18.2
# 21904              32.4              31.4              30.6              29.7
# 21905                ..  18.9966378233586  18.7776692069517                ..
# 21906              43.8              42.4              41.1              39.8
# 21907  177.298309844609  174.085100929693  173.472867275604  178.318112520384
# 21908  116.391670742655  116.083524344293   115.54781327774  119.911900229058
# 21909                ..                ..  11.7590910002673                ..
# 21910                ..  1.46411063791079  1.45141154191923                ..
# 21911                ..                ..                ..                ..
#
#       2018 [YR2018]
# 21902            ..
# 21903          17.7
# 21904          28.9
# 21905            ..
# 21906          38.6
# 21907            ..
# 21908            ..
# 21909            ..
# 21910            ..
# 21911            ..
#
# [10 rows x 63 columns]

# %%
trimmed_worldbank_data.shape
# Out:
# (21912, 63)

# %% [markdown]
# ### Stage 4.3 - Filtering
#  This part of the process will:
#  - Filter down to the set of "Series Name" that I am interested in analysing.
#
#  Hypothesis : the following broad classes of data are likely to have the biggest impact on *Life Expectency* and *Population Growth*:
#  1. Measures of economic properity:
#  2. Access to energy;
#  3. Environment measurements;
#  4. Access to education and technology;
#
#  Suitable series are now selected from the World Bank Data below.

# %%
list_of_series_names = [\
    # The two primary data series that I want to explore are Life Expectancy and Population Growth, so lets select those first:
    "Life expectancy at birth, total (years)",\
    #"Life expectancy at birth, male (years)",\
    #"Life expectancy at birth, female (years)",\
    "Population growth (annual %)",\
    "Population, total",\
    #"Population, male (% of total population)",\
    #"Population, female (% of total population)",\
    #
    # Measures of economic prosperity
    "GDP per capita (current US$)",\
    "Inflation, consumer prices (annual %)",\
    "Market capitalization of listed domestic companies (current US$)",\
    "Tax revenue (% of GDP)",\
    "Merchandise exports (current US$)",\
    #
    # Access to clean, reliable energy
    "Electric power consumption (kWh per capita)",\
    "Energy use (kg of oil equivalent per capita)",\
    "Power outages in firms in a typical month (number)",\
    "Fossil fuel energy consumption (% of total)",\
    "Renewable energy consumption (% of total final energy consumption)",\
    #
    # Environmental measures
    "Urban population growth (annual %)",\
    "Population density (people per sq. km of land area)",\
    #"Mortality rate attributed to unsafe water, unsafe sanitation and lack of hygiene (per 100,000 population)",\
    #"Mortality caused by road traffic injury (per 100,000 people)",\
    #"Mortality rate attributed to household and ambient air pollution, age-standardized (per 100,000 population)",\
    "Suicide mortality rate (per 100,000 population)",\
    # 
    # Access to education, healthcare and technology
    "Immunization, DPT (% of children ages 12-23 months)",\
    "Mobile cellular subscriptions (per 100 people)",\
    "Account ownership at a financial institution or with a mobile-money-service provider, young adults (% of population ages 15-24)",\
    "Mortality rate, infant (per 1,000 live births)"]

# %%
# Now use this list of Series Name to appply this filter to the data:
filtered_worldbank_data = trimmed_worldbank_data.loc[trimmed_worldbank_data['Series Name'].isin(list_of_series_names)]

# %%
filtered_worldbank_data["Series Name"].value_counts()
# Out:
# Suicide mortality rate (per 100,000 population)                                                                                    264
# Tax revenue (% of GDP)                                                                                                             264
# Mobile cellular subscriptions (per 100 people)                                                                                     264
# GDP per capita (current US$)                                                                                                       264
# Electric power consumption (kWh per capita)                                                                                        264
# Fossil fuel energy consumption (% of total)                                                                                        264
# Immunization, DPT (% of children ages 12-23 months)                                                                                264
# Merchandise exports (current US$)                                                                                                  264
# Inflation, consumer prices (annual %)                                                                                              264
# Urban population growth (annual %)                                                                                                 264
# Population, total                                                                                                                  264
# Mortality rate, infant (per 1,000 live births)                                                                                     264
# Renewable energy consumption (% of total final energy consumption)                                                                 264
# Energy use (kg of oil equivalent per capita)                                                                                       264
# Life expectancy at birth, total (years)                                                                                            264
# Account ownership at a financial institution or with a mobile-money-service provider, young adults (% of population ages 15-24)    264
# Market capitalization of listed domestic companies (current US$)                                                                   264
# Population density (people per sq. km of land area)                                                                                264
# Power outages in firms in a typical month (number)                                                                                 264
# Population growth (annual %)                                                                                                       264
# Name: Series Name, dtype: int64

# %% [markdown]
# ### Stage 4.4 - Process Blank Cells
#  One simple step is required at this stage to clean up the cells that to contain no data : that is to replace the instances of ".." with NaN.

# %%
cleansed_world_data = filtered_worldbank_data.replace(to_replace='..', value=np.nan)

# %% [markdown]
# ### Stage 4.5 - Unpivoting
#  This part of the process will:
#  - Rename the year columns - a pre-quisite to support the next step;
#  - Unpivot the data such that the individual year columns are collapsed into single column to achieve a "thin and tall" data structure;
#  - Pivot the data such that the individual series data are each placed into their own columns to achieve a "fatter and less tall" data stucture.

# %%
reshaped_worldbank_data, column_list = hf.trim_year_column_names(cleansed_world_data)

# %%
reshaped_worldbank_data.shape
# Out:
# (5280, 63)

# %%
reshaped_worldbank_data = pd.melt(reshaped_worldbank_data, id_vars=['Series Name', 'Series Code', 'Country Name', 'Country Code'])

# %%
reshaped_worldbank_data = reshaped_worldbank_data.rename(columns = { "variable" : "Year"})

# %%
reshaped_worldbank_data = reshaped_worldbank_data.astype({"value" : "float"})

# %%
reshaped_worldbank_data.shape
# Out:
# (311520, 6)

# %%
reshaped_worldbank_data.head(5)
# Out:
#                                          Series Name        Series Code  \
# 0                                  Population, total        SP.POP.TOTL
# 1            Life expectancy at birth, total (years)     SP.DYN.LE00.IN
# 2                       GDP per capita (current US$)     NY.GDP.PCAP.CD
# 3        Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 4  Power outages in firms in a typical month (num...        IC.ELC.OUTG
#
#   Country Name Country Code  Year         value
# 0  Afghanistan          AFG  1960  8.996973e+06
# 1  Afghanistan          AFG  1960  3.244600e+01
# 2  Afghanistan          AFG  1960  5.977319e+01
# 3  Afghanistan          AFG  1960           NaN
# 4  Afghanistan          AFG  1960           NaN

# %% [markdown]
# ### Stage 4.6 - Add Country Metadata
#  Here we prepare the World Bank country metadata

# %%
raw_worldbank_country_metadata.columns
# Out:
# Index(['Code', 'Long Name', 'Income Group', 'Region', 'Lending category',
#        'Other groups', 'Currency Unit', 'Latest population census',
#        'Latest household survey', 'Special Notes',
#        'National accounts base year', 'National accounts reference year',
#        'System of National Accounts', 'SNA price valuation',
#        'Alternative conversion factor', 'PPP survey year',
#        'Balance of Payments Manual in use', 'External debt Reporting status',
#        'System of trade', 'Government Accounting concept',
#        'IMF data dissemination standard',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data', '2-alpha code',
#        'WB-2 code', 'Table Name', 'Short Name'],
#       dtype='object')

# %%
country_metadata = raw_worldbank_country_metadata[["Code", "Short Name", "Income Group", "Region"]]

# %%
country_metadata = country_metadata.rename(columns = { "Short Name" : "Country"})

# %%
country_metadata.head(10)
# Out:
#   Code              Country         Income Group                      Region
# 0  AFG          Afghanistan           Low income                  South Asia
# 1  ALB              Albania  Upper middle income       Europe & Central Asia
# 2  DZA              Algeria  Upper middle income  Middle East & North Africa
# 3  ASM       American Samoa  Upper middle income         East Asia & Pacific
# 4  AND              Andorra          High income       Europe & Central Asia
# 5  AGO               Angola  Lower middle income          Sub-Saharan Africa
# 6  ATG  Antigua and Barbuda          High income   Latin America & Caribbean
# 7  ARG            Argentina  Upper middle income   Latin America & Caribbean
# 8  ARM              Armenia  Upper middle income       Europe & Central Asia
# 9  ABW                Aruba          High income   Latin America & Caribbean

# %% [markdown]
#  There are a number of "dummy" countries that have empty Region and Income Group data - these will ultimately be dropped from the data when the pivot stage is applied below.

# %%
country_metadata.loc[pd.isnull(country_metadata["Region"])]
# Out:
#     Code                                            Country Income Group  \
# 217  ARB                                         Arab World          NaN
# 218  CSS                             Caribbean small states          NaN
# 219  CEB                     Central Europe and the Baltics          NaN
# 220  EAR                         Early-demographic dividend          NaN
# 221  EAS                                East Asia & Pacific          NaN
# 222  EAP        East Asia & Pacific (excluding high income)          NaN
# 223  TEA                   East Asia & Pacific (IDA & IBRD)          NaN
# 224  EMU                                          Euro area          NaN
# 225  ECS                              Europe & Central Asia          NaN
# 226  ECA      Europe & Central Asia (excluding high income)          NaN
# 227  TEC                 Europe & Central Asia (IDA & IBRD)          NaN
# 228  EUU                                     European Union          NaN
# 229  FCS           Fragile and conflict affected situations          NaN
# 230  HPC             Heavily indebted poor countries (HIPC)          NaN
# 231  HIC                                        High income          NaN
# 232  IBD                                          IBRD only          NaN
# 233  IBT                                   IDA & IBRD total          NaN
# 234  IDB                                          IDA blend          NaN
# 235  IDX                                           IDA only          NaN
# 236  IDA                                          IDA total          NaN
# 237  LTE                          Late-demographic dividend          NaN
# 238  LCN                          Latin America & Caribbean          NaN
# 239  LAC  Latin America & Caribbean (excluding high income)          NaN
# 240  TLA             Latin America & Caribbean (IDA & IBRD)          NaN
# 241  LDC       Least developed countries: UN classification          NaN
# 242  LMY                                Low & middle income          NaN
# 243  LIC                                         Low income          NaN
# 244  LMC                                Lower middle income          NaN
# 245  MEA                         Middle East & North Africa          NaN
# 246  MNA  Middle East & North Africa (excluding high inc...          NaN
# 247  TMN            Middle East & North Africa (IDA & IBRD)          NaN
# 248  MIC                                      Middle income          NaN
# 249  NAC                                      North America          NaN
# 250  OED                                       OECD members          NaN
# 251  OSS                                 Other small states          NaN
# 252  PSS                        Pacific island small states          NaN
# 253  PST                          Post-demographic dividend          NaN
# 254  PRE                           Pre-demographic dividend          NaN
# 255  SST                                       Small states          NaN
# 256  SAS                                         South Asia          NaN
# 257  TSA                            South Asia (IDA & IBRD)          NaN
# 258  SSF                                 Sub-Saharan Africa          NaN
# 259  SSA         Sub-Saharan Africa (excluding high income)          NaN
# 260  TSS                    Sub-Saharan Africa (IDA & IBRD)          NaN
# 261  UMC                                Upper middle income          NaN
# 262  WLD                                              World          NaN
#
#     Region
# 217    NaN
# 218    NaN
# 219    NaN
# 220    NaN
# 221    NaN
# 222    NaN
# 223    NaN
# 224    NaN
# 225    NaN
# 226    NaN
# 227    NaN
# 228    NaN
# 229    NaN
# 230    NaN
# 231    NaN
# 232    NaN
# 233    NaN
# 234    NaN
# 235    NaN
# 236    NaN
# 237    NaN
# 238    NaN
# 239    NaN
# 240    NaN
# 241    NaN
# 242    NaN
# 243    NaN
# 244    NaN
# 245    NaN
# 246    NaN
# 247    NaN
# 248    NaN
# 249    NaN
# 250    NaN
# 251    NaN
# 252    NaN
# 253    NaN
# 254    NaN
# 255    NaN
# 256    NaN
# 257    NaN
# 258    NaN
# 259    NaN
# 260    NaN
# 261    NaN
# 262    NaN

# %% [markdown]
#  Here we will extend the World Bank data with country metadata (Region, Income Group) by merging the two data sets.

# %%
merged_data = reshaped_worldbank_data.merge(country_metadata, left_on="Country Code", right_on="Code")

# %%
merged_data.head(10)
# Out:
#                                          Series Name        Series Code  \
# 0                                  Population, total        SP.POP.TOTL
# 1            Life expectancy at birth, total (years)     SP.DYN.LE00.IN
# 2                       GDP per capita (current US$)     NY.GDP.PCAP.CD
# 3        Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 4  Power outages in firms in a typical month (num...        IC.ELC.OUTG
# 5       Energy use (kg of oil equivalent per capita)  EG.USE.PCAP.KG.OE
# 6        Fossil fuel energy consumption (% of total)  EG.USE.COMM.FO.ZS
# 7  Renewable energy consumption (% of total final...     EG.FEC.RNEW.ZS
# 8              Inflation, consumer prices (annual %)     FP.CPI.TOTL.ZG
# 9     Mobile cellular subscriptions (per 100 people)     IT.CEL.SETS.P2
#
#   Country Name Country Code  Year         value Code      Country  \
# 0  Afghanistan          AFG  1960  8.996973e+06  AFG  Afghanistan
# 1  Afghanistan          AFG  1960  3.244600e+01  AFG  Afghanistan
# 2  Afghanistan          AFG  1960  5.977319e+01  AFG  Afghanistan
# 3  Afghanistan          AFG  1960           NaN  AFG  Afghanistan
# 4  Afghanistan          AFG  1960           NaN  AFG  Afghanistan
# 5  Afghanistan          AFG  1960           NaN  AFG  Afghanistan
# 6  Afghanistan          AFG  1960           NaN  AFG  Afghanistan
# 7  Afghanistan          AFG  1960           NaN  AFG  Afghanistan
# 8  Afghanistan          AFG  1960           NaN  AFG  Afghanistan
# 9  Afghanistan          AFG  1960  0.000000e+00  AFG  Afghanistan
#
#   Income Group      Region
# 0   Low income  South Asia
# 1   Low income  South Asia
# 2   Low income  South Asia
# 3   Low income  South Asia
# 4   Low income  South Asia
# 5   Low income  South Asia
# 6   Low income  South Asia
# 7   Low income  South Asia
# 8   Low income  South Asia
# 9   Low income  South Asia

# %%
merged_data["Country Name"].value_counts()
# Out:
# Germany                  1180
# Tunisia                  1180
# Micronesia, Fed. Sts.    1180
# Nepal                    1180
# Bahamas, The             1180
#                          ...
# Chad                     1180
# Paraguay                 1180
# India                    1180
# Serbia                   1180
# China                    1180
# Name: Country Name, Length: 263, dtype: int64

# %% [markdown]
# ### Stage 1.7 - Add Decade Label
#  Here we process the Year colun to create a useful Decade column and convert Year from a string into an integer.

# %%
merged_data["Decade"] = merged_data["Year"].str.slice(start=0, stop=3) + "0s"

# %%
merged_data = merged_data.astype({"Year" : "int"})

# %%
merged_data.head(10)
# Out:
#                                          Series Name        Series Code  \
# 0                                  Population, total        SP.POP.TOTL
# 1            Life expectancy at birth, total (years)     SP.DYN.LE00.IN
# 2                       GDP per capita (current US$)     NY.GDP.PCAP.CD
# 3        Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 4  Power outages in firms in a typical month (num...        IC.ELC.OUTG
# 5       Energy use (kg of oil equivalent per capita)  EG.USE.PCAP.KG.OE
# 6        Fossil fuel energy consumption (% of total)  EG.USE.COMM.FO.ZS
# 7  Renewable energy consumption (% of total final...     EG.FEC.RNEW.ZS
# 8              Inflation, consumer prices (annual %)     FP.CPI.TOTL.ZG
# 9     Mobile cellular subscriptions (per 100 people)     IT.CEL.SETS.P2
#
#   Country Name Country Code  Year         value Code      Country  \
# 0  Afghanistan          AFG  1960  8.996973e+06  AFG  Afghanistan
# 1  Afghanistan          AFG  1960  3.244600e+01  AFG  Afghanistan
# 2  Afghanistan          AFG  1960  5.977319e+01  AFG  Afghanistan
# 3  Afghanistan          AFG  1960           NaN  AFG  Afghanistan
# 4  Afghanistan          AFG  1960           NaN  AFG  Afghanistan
# 5  Afghanistan          AFG  1960           NaN  AFG  Afghanistan
# 6  Afghanistan          AFG  1960           NaN  AFG  Afghanistan
# 7  Afghanistan          AFG  1960           NaN  AFG  Afghanistan
# 8  Afghanistan          AFG  1960           NaN  AFG  Afghanistan
# 9  Afghanistan          AFG  1960  0.000000e+00  AFG  Afghanistan
#
#   Income Group      Region Decade
# 0   Low income  South Asia  1960s
# 1   Low income  South Asia  1960s
# 2   Low income  South Asia  1960s
# 3   Low income  South Asia  1960s
# 4   Low income  South Asia  1960s
# 5   Low income  South Asia  1960s
# 6   Low income  South Asia  1960s
# 7   Low income  South Asia  1960s
# 8   Low income  South Asia  1960s
# 9   Low income  South Asia  1960s

# %%
merged_data.tail(10)
# Out:
#                                               Series Name        Series Code  \
# 310330  Account ownership at a financial institution o...  FX.OWN.TOTL.YG.ZS
# 310331  Population density (people per sq. km of land ...        EN.POP.DNST
# 310332                       Population growth (annual %)        SP.POP.GROW
# 310333                 Urban population growth (annual %)        SP.URB.GROW
# 310334                  Merchandise exports (current US$)  TX.VAL.MRCH.CD.WT
# 310335  Market capitalization of listed domestic compa...     CM.MKT.LCAP.CD
# 310336  Immunization, DPT (% of children ages 12-23 mo...        SH.IMM.IDPT
# 310337                             Tax revenue (% of GDP)  GC.TAX.TOTL.GD.ZS
# 310338    Suicide mortality rate (per 100,000 population)     SH.STA.SUIC.P5
# 310339     Mortality rate, infant (per 1,000 live births)     SP.DYN.IMRT.IN
#
#        Country Name Country Code  Year         value Code Country  \
# 310330        World          WLD  2018           NaN  WLD   World
# 310331        World          WLD  2018  5.963624e+01  WLD   World
# 310332        World          WLD  2018  1.108774e+00  WLD   World
# 310333        World          WLD  2018  1.935715e+00  WLD   World
# 310334        World          WLD  2018  1.960045e+13  WLD   World
# 310335        World          WLD  2018  6.865409e+13  WLD   World
# 310336        World          WLD  2018  8.586973e+01  WLD   World
# 310337        World          WLD  2018           NaN  WLD   World
# 310338        World          WLD  2018           NaN  WLD   World
# 310339        World          WLD  2018  2.890000e+01  WLD   World
#
#        Income Group Region Decade
# 310330          NaN    NaN  2010s
# 310331          NaN    NaN  2010s
# 310332          NaN    NaN  2010s
# 310333          NaN    NaN  2010s
# 310334          NaN    NaN  2010s
# 310335          NaN    NaN  2010s
# 310336          NaN    NaN  2010s
# 310337          NaN    NaN  2010s
# 310338          NaN    NaN  2010s
# 310339          NaN    NaN  2010s

# %%
merged_data.dtypes
# Out:
# Series Name      object
# Series Code      object
# Country Name     object
# Country Code     object
# Year              int32
# value           float64
# Code             object
# Country          object
# Income Group     object
# Region           object
# Decade           object
# dtype: object

# %% [markdown]
# ### Stage 1.8 - Pivoting
#  This part of the process will:
#  1. Pivot the data such that the individual series data are each placed into their own columns to achieve a "fatter and less tall" data stucture;
#  2. In doing so, create a useful multi-index that can be used to slice and group data later in the process.

# %%
pivoted_worldbank_data = pd.pivot_table(merged_data, index=["Region", "Income Group", "Country", "Decade", "Year"], columns="Series Name", values="value")

# %%
# Rename super long column as it is a pain later in the process:
pivoted_worldbank_data = pivoted_worldbank_data.rename(columns = { "Account ownership at a financial institution or with a mobile-money-service provider, young adults (% of population ages 15-24)" \
 : "Account at financial institution (% of population ages 15-24)" })

# %%
pivoted_worldbank_data.shape
# Out:
# (12726, 20)

# %%
pivoted_worldbank_data.describe()
# Out:
# Series Name  Account at financial institution (% of population ages 15-24)  \
# count                                               427.000000
# mean                                                 44.536078
# std                                                  30.015059
# min                                                   0.000000
# 25%                                                  18.906853
# 50%                                                  37.984398
# 75%                                                  70.307777
# max                                                 100.000000
#
# Series Name  Electric power consumption (kWh per capita)  \
# count                                        5907.000000
# mean                                         3173.076628
# std                                          4446.376151
# min                                             0.000000
# 25%                                           399.509265
# 50%                                          1574.391404
# 75%                                          4305.076959
# max                                         54799.174708
#
# Series Name  Energy use (kg of oil equivalent per capita)  \
# count                                         6082.000000
# mean                                          2348.631092
# std                                           3026.611948
# min                                              0.000000
# 25%                                            512.679375
# 50%                                           1212.125397
# 75%                                           3067.663829
# max                                          40710.112176
#
# Series Name  Fossil fuel energy consumption (% of total)  \
# count                                        5860.000000
# mean                                           66.421132
# std                                            30.660445
# min                                             0.000000
# 25%                                            43.421139
# 50%                                            76.479407
# 75%                                            92.886309
# max                                           100.000000
#
# Series Name  GDP per capita (current US$)  \
# count                         9675.000000
# mean                          8172.122518
# std                          16101.936489
# min                             34.790581
# 25%                            513.870461
# 50%                           1864.536803
# 75%                           7708.915191
# max                         189170.895671
#
# Series Name  Immunization, DPT (% of children ages 12-23 months)  \
# count                                              6871.000000
# mean                                                 79.063601
# std                                                  22.790947
# min                                                   1.000000
# 25%                                                  71.000000
# 50%                                                  88.000000
# 75%                                                  96.000000
# max                                                  99.000000
#
# Series Name  Inflation, consumer prices (annual %)  \
# count                                  7671.000000
# mean                                     25.078948
# std                                     344.911953
# min                                     -18.108630
# 25%                                       2.191332
# 50%                                       5.040832
# 75%                                      10.579520
# max                                   23773.131774
#
# Series Name  Life expectancy at birth, total (years)  \
# count                                   11329.000000
# mean                                       64.000279
# std                                        11.454812
# min                                        18.907000
# 25%                                        55.907000
# 50%                                        67.134000
# 75%                                        72.618000
# max                                        85.417073
#
# Series Name  Market capitalization of listed domestic companies (current US$)  \
# count                                             2.199000e+03
# mean                                              5.166738e+11
# std                                               2.084727e+12
# min                                               3.040000e+06
# 25%                                               7.169470e+09
# 50%                                               4.408117e+10
# 75%                                               2.352539e+11
# max                                               3.212070e+13
#
# Series Name  Merchandise exports (current US$)  \
# count                             1.038000e+04
# mean                              3.172074e+10
# std                               1.262465e+11
# min                               0.000000e+00
# 25%                               1.550000e+08
# 50%                               1.120000e+09
# 75%                               9.185500e+09
# max                               2.487045e+12
#
# Series Name  Mobile cellular subscriptions (per 100 people)  \
# count                                           9418.000000
# mean                                              30.210696
# std                                               47.816411
# min                                                0.000000
# 25%                                                0.000000
# 50%                                                0.241671
# 75%                                               53.541517
# max                                              345.324522
#
# Series Name  Mortality rate, infant (per 1,000 live births)  \
# count                                          10097.000000
# mean                                              51.738219
# std                                               45.985846
# min                                                1.400000
# 25%                                               14.600000
# 50%                                               37.300000
# 75%                                               77.900000
# max                                              279.400000
#
# Series Name  Population density (people per sq. km of land area)  \
# count                                             12162.000000
# mean                                                328.717642
# std                                                1583.854763
# min                                                   0.098625
# 25%                                                  20.253278
# 50%                                                  65.731890
# 75%                                                 153.066933
# max                                               21389.100000
#
# Series Name  Population growth (annual %)  Population, total  \
# count                        12690.000000       1.269500e+04
# mean                             1.801935       2.415184e+07
# std                              1.673228       1.014191e+08
# min                            -10.955149       3.893000e+03
# 25%                              0.735368       4.628345e+05
# 50%                              1.737298       4.099702e+06
# 75%                              2.680775       1.311979e+07
# max                             28.059956       1.392730e+09
#
# Series Name  Power outages in firms in a typical month (number)  \
# count                                               259.000000
# mean                                                  6.579923
# std                                                  12.273851
# min                                                   0.000000
# 25%                                                   0.750000
# 50%                                                   1.900000
# 75%                                                   6.400000
# max                                                 100.700000
#
# Series Name  Renewable energy consumption (% of total final energy consumption)  \
# count                                              5392.000000
# mean                                                 30.752026
# std                                                  31.071563
# min                                                   0.000000
# 25%                                                   3.228826
# 50%                                                  18.646600
# 75%                                                  54.072173
# max                                                  98.342602
#
# Series Name  Suicide mortality rate (per 100,000 population)  \
# count                                             915.000000
# mean                                                9.935628
# std                                                 7.267047
# min                                                 0.300000
# 25%                                                 4.900000
# 50%                                                 8.100000
# 75%                                                12.700000
# max                                                52.600000
#
# Series Name  Tax revenue (% of GDP)  Urban population growth (annual %)
# count                   3843.000000                        12573.000000
# mean                      16.980142                            2.967728
# std                        7.171823                            3.035699
# min                        0.000108                         -187.141962
# 25%                       11.882260                            1.186377
# 50%                       16.406379                            2.667568
# 75%                       21.688350                            4.326036
# max                       62.858611                           48.935720

# %%
pivoted_worldbank_data.head(10)
# Out:
#  1964                                    87.975807
#                                                   1965                                    88.041991
#                                                   1966                                    89.241769
#                                                   1967                                    89.500850
#                                                   1968                                    90.104615
#                                                   1969                                    90.269620
#
# Series Name                                             GDP per capita (current US$)  \
# Region              Income Group Country   Decade Year
# East Asia & Pacific High income  Australia 1960s  1960                   1807.785710
#                                                   1961                   1874.838940
#                                                   1962                   1851.841851
#                                                   1963                   1964.150470
#                                                   1964                   2128.068355
#                                                   1965                   2277.656742
#                                                   1966                   2340.438685
#                                                   1967                   2576.284509
#                                                   1968                   2720.082609
#                                                   1969                   2986.949507
#
# Series Name                                             Immunization, DPT (% of children ages 12-23 months)  \
# Region              Income Group Country   Decade Year
# East Asia & Pacific High income  Australia 1960s  1960                                                NaN
#                                                   1961                                                NaN
#                                                   1962                                                NaN
#                                                   1963                                                NaN
#                                                   1964                                                NaN
#                                                   1965                                                NaN
#                                                   1966                                                NaN
#                                                   1967                                                NaN
#                                                   1968                                                NaN
#                                                   1969                                                NaN
#
# Series Name                                             Inflation, consumer prices (annual %)  \
# Region              Income Group Country   Decade Year
# East Asia & Pacific High income  Australia 1960s  1960                               3.728814
#                                                   1961                               2.287582
#                                                   1962                              -0.319489
#                                                   1963                               0.641026
#                                                   1964                               2.866242
#                                                   1965                               3.405573
#                                                   1966                               3.293413
#                                                   1967                               3.478261
#                                                   1968                               2.521008
#                                                   1969                               3.278689
#
# Series Name                                             Life expectancy at birth, total (years)  \
# Region              Income Group Country   Decade Year
# East Asia & Pacific High income  Australia 1960s  1960                                70.817073
#                                                   1961                                70.973171
#                                                   1962                                70.942439
#                                                   1963                                70.911707
#                                                   1964                                70.880976
#                                                   1965                                70.850244
#                                                   1966                                70.819512
#                                                   1967                                70.869268
#                                                   1968                                70.919024
#                                                   1969                                70.968780
#
# Series Name                                             Market capitalization of listed domestic companies (current US$)  \
# Region              Income Group Country   Decade Year
# East Asia & Pacific High income  Australia 1960s  1960                                                NaN
#                                                   1961                                                NaN
#                                                   1962                                                NaN
#                                                   1963                                                NaN
#                                                   1964                                                NaN
#                                                   1965                                                NaN
#                                                   1966                                                NaN
#                                                   1967                                                NaN
#                                                   1968                                                NaN
#                                                   1969                                                NaN
#
# Series Name                                             Merchandise exports (current US$)  \
# Region              Income Group Country   Decade Year
# East Asia & Pacific High income  Australia 1960s  1960                       2.050000e+09
#                                                   1961                       2.363000e+09
#                                                   1962                       2.356000e+09
#                                                   1963                       2.805000e+09
#                                                   1964                       3.053000e+09
#                                                   1965                       3.005000e+09
#                                                   1966                       3.171000e+09
#                                                   1967                       3.478000e+09
#                                                   1968                       3.526000e+09
#                                                   1969                       4.220000e+09
#
# Series Name                                             Mobile cellular subscriptions (per 100 people)  \
# Region              Income Group Country   Decade Year
# East Asia & Pacific High income  Australia 1960s  1960                                             0.0
#                                                   1961                                             NaN
#                                                   1962                                             NaN
#                                                   1963                                             NaN
#                                                   1964                                             NaN
#                                                   1965                                             0.0
#                                                   1966                                             NaN
#                                                   1967                                             NaN
#                                                   1968                                             NaN
#                                                   1969                                             NaN
#
# Series Name                                             Mortality rate, infant (per 1,000 live births)  \
# Region              Income Group Country   Decade Year
# East Asia & Pacific High income  Australia 1960s  1960                                            20.3
#                                                   1961                                            19.9
#                                                   1962                                            19.5
#                                                   1963                                            19.1
#                                                   1964                                            18.7
#                                                   1965                                            18.5
#                                                   1966                                            18.3
#                                                   1967                                            18.2
#                                                   1968                                            18.1
#                                                   1969                                            18.0
#
# Series Name                                             Population density (people per sq. km of land area)  \
# Region              Income Group Country   Decade Year
# East Asia & Pacific High income  Australia 1960s  1960                                                NaN
#                                                   1961                                           1.364565
#                                                   1962                                           1.398279
#                                                   1963                                           1.425354
#                                                   1964                                           1.453601
#                                                   1965                                           1.482369
#                                                   1966                                           1.516603
#                                                   1967                                           1.535868
#                                                   1968                                           1.563204
#                                                   1969                                           1.596267
#
# Series Name                                             Population growth (annual %)  \
# Region              Income Group Country   Decade Year
# East Asia & Pacific High income  Australia 1960s  1960                      2.266912
#                                                   1961                      1.989740
#                                                   1962                      2.440639
#                                                   1963                      1.917816
#                                                   1964                      1.962354
#                                                   1965                      1.959717
#                                                   1966                      2.283184
#                                                   1967                      1.262277
#                                                   1968                      1.764159
#                                                   1969                      2.093023
#
# Series Name                                             Population, total  \
# Region              Income Group Country   Decade Year
# East Asia & Pacific High income  Australia 1960s  1960         10276477.0
#                                                   1961         10483000.0
#                                                   1962         10742000.0
#                                                   1963         10950000.0
#                                                   1964         11167000.0
#                                                   1965         11388000.0
#                                                   1966         11651000.0
#                                                   1967         11799000.0
#                                                   1968         12009000.0
#                                                   1969         12263000.0
#
# Series Name                                             Power outages in firms in a typical month (number)  \
# Region              Income Group Country   Decade Year
# East Asia & Pacific High income  Australia 1960s  1960                                                NaN
#                                                   1961                                                NaN
#                                                   1962                                                NaN
#                                                   1963                                                NaN
#                                                   1964                                                NaN
#                                                   1965                                                NaN
#                                                   1966                                                NaN
#                                                   1967                                                NaN
#                                                   1968                                                NaN
#                                                   1969                                                NaN
#
# Series Name                                             Renewable energy consumption (% of total final energy consumption)  \
# Region              Income Group Country   Decade Year
# East Asia & Pacific High income  Australia 1960s  1960                                                NaN
#                                                   1961                                                NaN
#                                                   1962                                                NaN
#                                                   1963                                                NaN
#                                                   1964                                                NaN
#                                                   1965                                                NaN
#                                                   1966                                                NaN
#                                                   1967                                                NaN
#                                                   1968                                                NaN
#                                                   1969                                                NaN
#
# Series Name                                             Suicide mortality rate (per 100,000 population)  \
# Region              Income Group Country   Decade Year
# East Asia & Pacific High income  Australia 1960s  1960                                              NaN
#                                                   1961                                              NaN
#                                                   1962                                              NaN
#                                                   1963                                              NaN
#                                                   1964                                              NaN
#                                                   1965                                              NaN
#                                                   1966                                              NaN
#                                                   1967                                              NaN
#                                                   1968                                              NaN
#                                                   1969                                              NaN
#
# Series Name                                             Tax revenue (% of GDP)  \
# Region              Income Group Country   Decade Year
# East Asia & Pacific High income  Australia 1960s  1960                     NaN
#                                                   1961                     NaN
#                                                   1962                     NaN
#                                                   1963                     NaN
#                                                   1964                     NaN
#                                                   1965                     NaN
#                                                   1966                     NaN
#                                                   1967                     NaN
#                                                   1968                     NaN
#                                                   1969                     NaN
#
# Series Name                                             Urban population growth (annual %)
# Region              Income Group Country   Decade Year
# East Asia & Pacific High income  Australia 1960s  1960                            2.783396
#                                                   1961                            2.493808
#                                                   1962                            2.790283
#                                                   1963                            2.261393
#                                                   1964                            2.302335
#                                                   1965                            2.292526
#                                                   1966                            2.610086
#                                                   1967                            1.462465
#                                                   1968                            1.961546
#                                                   1969                            2.288843

# %%
pivoted_worldbank_data.reset_index()["Country"].value_counts()
# Out:
# Australia                    59
# Colombia                     59
# Belize                       59
# Malaysia                     59
# India                        59
#                              ..
# Mexico                       59
# Peru                         59
# West Bank and Gaza           44
# Serbia                       35
# Sint Maarten (Dutch part)    21
# Name: Country, Length: 217, dtype: int64

# %%
pivoted_worldbank_data.dtypes
# Out:
# Series Name
# Account at financial institution (% of population ages 15-24)         float64
# Electric power consumption (kWh per capita)                           float64
# Energy use (kg of oil equivalent per capita)                          float64
# Fossil fuel energy consumption (% of total)                           float64
# GDP per capita (current US$)                                          float64
# Immunization, DPT (% of children ages 12-23 months)                   float64
# Inflation, consumer prices (annual %)                                 float64
# Life expectancy at birth, total (years)                               float64
# Market capitalization of listed domestic companies (current US$)      float64
# Merchandise exports (current US$)                                     float64
# Mobile cellular subscriptions (per 100 people)                        float64
# Mortality rate, infant (per 1,000 live births)                        float64
# Population density (people per sq. km of land area)                   float64
# Population growth (annual %)                                          float64
# Population, total                                                     float64
# Power outages in firms in a typical month (number)                    float64
# Renewable energy consumption (% of total final energy consumption)    float64
# Suicide mortality rate (per 100,000 population)                       float64
# Tax revenue (% of GDP)                                                float64
# Urban population growth (annual %)                                    float64
# dtype: object

# %% [markdown]
# ### Stage 1.9 - Write To File
#  Now we write the resulting data frame to the Pickle file format to preserve all meta data.

# %%
pivoted_worldbank_data.to_pickle(data_path + "pivoted_worldbank_data.pkl")
